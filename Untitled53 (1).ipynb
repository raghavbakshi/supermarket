# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
df=pd.read_csv(r"C:\Users\Dell\Downloads\SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# postal code is a numeric number but actually represents an unique are code so we will convert its type to object
df['Postal Code']=df['Postal Code'].astype('object')

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
# printing the number of unique labels inside columns
for col in df.columns:
    print(col,':', len(df[col].unique()),'labels')
# Out:
# Ship Mode : 4 labels
# Segment : 3 labels
# Country : 1 labels
# City : 531 labels
# State : 49 labels
# Postal Code : 631 labels
# Region : 4 labels
# Category : 3 labels
# Sub-Category : 17 labels
# Sales : 5825 labels
# Quantity : 14 labels
# Discount : 12 labels
# Profit : 7287 labels

# %% [markdown]
# # Numerical Features

# %%
numercial_features=[features for features in df.columns if df[features].dtype!='object']
numercial_features
# Out:
# ['Sales', 'Quantity', 'Discount', 'Profit']

# %%
df_numerical_features=df[['Sales','Quantity','Discount','Profit']]

# %% [markdown]
# # Categorical Features

# %%
categorical_features=[features for features in df.columns if df[features].dtype=='object']
categorical_features
# Out:
# ['Ship Mode',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal Code',
#  'Region',
#  'Category',
#  'Sub-Category']

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# # 1) Ship Mode

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
sns.catplot(x='Ship Mode',kind='count',data=df)

# %% [markdown]
#  This implies majority of people are ordering through Standard class

# %% [markdown]
# # 2) Segment

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
sns.catplot(x='Segment',kind='count',data=df)

# %% [markdown]
# Consumer segment has the highest number of orders

# %% [markdown]
# # 3) City

# %%
df['City'].value_counts()
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Elyria               1
# Missouri City        1
# Romeoville           1
# Rochester Hills      1
# Hagerstown           1
# Name: City, Length: 531, dtype: int64

# %% [markdown]
# New York City has the highest orders

# %% [markdown]
# # 4) State

# %%
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %% [markdown]
# California State has the highest orders

# %% [markdown]
# # 5) Region

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
sns.catplot(x='Region',data=df,kind='count')

# %% [markdown]
# West region has most number of orders

# %% [markdown]
# # 6) Category

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.catplot(x='Category',data=df,kind='count')

# %% [markdown]
# Mostly Office Supplies are ordered

# %% [markdown]
# # 7) Sub-Categories

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
sns.catplot(x='Sub-Category',data=df,kind='count',aspect=3,order=df['Sub-Category'].value_counts().index)

# %% [markdown]
# Blinders are the highest selling product

# %% [markdown]
# # 8) Quantity

# %%
plt.figure(figsize=(12,12))
sns.countplot(x='Quantity',data=df,order=df['Quantity'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Generally People buy 3 quantity of goods

# %% [markdown]
# # 9) Discount

# %%
plt.figure(figsize=(12,12))
sns.countplot(x='Discount',data=df,order=df['Discount'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Most of the people buy on 0.00 % discount

# %% [markdown]
# # Bivariate Analysis

# %%
# ship mode and segment
df['Segment'].groupby(df['Ship Mode']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Ship Mode       Segment
# Standard Class  Consumer       3085
#                 Corporate      1812
#                 Home Office    1071
# Second Class    Consumer       1020
# First Class     Consumer        769
# Second Class    Corporate       609
# First Class     Corporate       485
# Same Day        Consumer        317
# Second Class    Home Office     316
# First Class     Home Office     284
# Name: Segment, dtype: int64

# %% [markdown]
# Most of the goods are bought by consumers by standard mode of shipment

# %%
# ship mode and city
df['City'].groupby(df['Ship Mode']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Ship Mode       City
# Standard Class  New York City    549
#                 Los Angeles      449
#                 Philadelphia     343
#                 San Francisco    287
#                 Seattle          249
#                 Houston          220
#                 Chicago          191
# Second Class    New York City    167
#                 Los Angeles      159
# First Class     New York City    147
# Name: City, dtype: int64

# %% [markdown]
# Most goods are being ordered from NeW York City by standard class

# %%
# ship mode and state
df['State'].groupby(df['Ship Mode']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Ship Mode       State
# Standard Class  California      1165
#                 New York         678
#                 Texas            602
# Second Class    California       395
# Standard Class  Pennsylvania     371
# First Class     California       322
# Standard Class  Illinois         295
#                 Washington       294
#                 Florida          234
#                 Ohio             230
# Name: State, dtype: int64

# %% [markdown]
# Most goods are being ordered from California State through Standard shipment

# %%
# ship mode and postal code
df['Postal Code'].groupby(df['Ship Mode']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Ship Mode       Postal Code
# Standard Class  10035          164
#                 10009          142
#                 94122          133
#                 10011          126
#                 10024          117
#                 19140          102
#                 19134          100
#                 90049           95
#                 98105           94
#                 98103           94
# Name: Postal Code, dtype: int64

# %% [markdown]
# Most of the goods are ordered from the postal code 10035

# %%
# ship mode and region
df['Region'].groupby(df['Ship Mode']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Ship Mode       Region
# Standard Class  West       1882
#                 East       1673
#                 Central    1439
#                 South       974
# Second Class    West        621
#                 East        530
# First Class     West        515
#                 East        490
# Second Class    Central     465
#                 South       329
# Name: Region, dtype: int64

# %% [markdown]
# Most of the goods are ordered from the West region through standard mode

# %%
# ship mode and categories
df['Category'].groupby(df['Ship Mode']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Ship Mode       Category
# Standard Class  Office Supplies    3638
#                 Furniture          1248
# Second Class    Office Supplies    1152
# Standard Class  Technology         1082
# First Class     Office Supplies     910
# Second Class    Furniture           427
#                 Technology          366
# First Class     Furniture           327
# Same Day        Office Supplies     326
# First Class     Technology          301
# Name: Category, dtype: int64

# %% [markdown]
# Office supplies are mostly ordered through Standard mode

# %%
# ship mode and sub categories
df['Sub-Category'].groupby(df['Ship Mode']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Ship Mode       Sub-Category
# Standard Class  Binders         947
#                 Paper           783
#                 Furnishings     575
#                 Phones          534
#                 Storage         504
#                 Art             493
#                 Accessories     444
#                 Chairs          359
# Second Class    Paper           289
# Standard Class  Appliances      288
# Name: Sub-Category, dtype: int64

# %% [markdown]
# Blinders are widely ordered through standard shipment

# %%
# ship mode and numeric variables
sns.pairplot(df,hue='Ship Mode')

# %%
#city and segment
df['City'].groupby(df['Segment']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Segment    City
# Consumer   New York City    504
#            Los Angeles      382
#            Philadelphia     269
# Corporate  New York City    266
# Consumer   San Francisco    260
# Corporate  Los Angeles      237
# Consumer   Seattle          219
#            Houston          212
# Corporate  Philadelphia     177
# Consumer   Chicago          174
# Name: City, dtype: int64

# %% [markdown]
# most of the orders from NYC are of consumers

# %%
# state and segment
df['State'].groupby(df['Segment']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Segment      State
# Consumer     California      1048
#              New York         643
# Corporate    California       618
# Consumer     Texas            524
# Home Office  California       335
# Corporate    New York         321
#              Texas            312
# Consumer     Pennsylvania     284
#              Illinois         276
#              Washington       275
# Name: State, dtype: int64

# %% [markdown]
# most of the orders are from california state and are of consumers

# %%
# region and segment
df['Region'].groupby(df['Segment']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Segment      Region
# Consumer     West       1672
#              East       1469
#              Central    1212
# Corporate    West        960
#              East        877
# Consumer     South       838
# Corporate    Central     673
# Home Office  West        571
# Corporate    South       510
# Home Office  East        502
# Name: Region, dtype: int64

# %% [markdown]
# people who order from west are mojorly consumers

# %%
# category and segment
df['Category'].groupby(df['Segment']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Segment      Category
# Consumer     Office Supplies    3127
# Corporate    Office Supplies    1820
# Consumer     Furniture          1113
# Home Office  Office Supplies    1079
# Consumer     Technology          951
# Corporate    Furniture           646
#              Technology          554
# Home Office  Furniture           362
#              Technology          342
# Name: Category, dtype: int64

# %% [markdown]
# mostly office supplies are odered by consumers

# %%
# Sub category and segment
df['Sub-Category'].groupby(df['Segment']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Segment    Sub-Category
# Consumer   Binders         780
#            Paper           693
#            Furnishings     494
# Corporate  Binders         473
# Consumer   Phones          451
#            Storage         450
#            Art             428
# Corporate  Paper           408
# Consumer   Accessories     408
#            Chairs          329
# Name: Sub-Category, dtype: int64

# %% [markdown]
# blinders are heavily ordered by consumers

# %%
# segent and numerical variables
sns.pairplot(df,hue='Segment')

# %%
# state and city
df['State'].groupby(df['City']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# City           State
# New York City  New York        915
# Los Angeles    California      747
# Philadelphia   Pennsylvania    537
# San Francisco  California      510
# Seattle        Washington      428
# Houston        Texas           377
# Chicago        Illinois        314
# San Diego      California      170
# Dallas         Texas           157
# Columbus       Ohio            120
# Name: State, dtype: int64

# %% [markdown]
# Most of the orders are from NYC

# %%
# city and region
df['Region'].groupby(df['City']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# City           Region
# New York City  East       915
# Los Angeles    West       747
# Philadelphia   East       537
# San Francisco  West       510
# Seattle        West       428
# Houston        Central    377
# Chicago        Central    314
# San Diego      West       170
# Dallas         Central    157
# Jacksonville   South      125
# Name: Region, dtype: int64

# %% [markdown]
# most of the orders are from east region of NYC

# %%
# city and category
df['Category'].groupby(df['City']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# City           Category
# New York City  Office Supplies    552
# Los Angeles    Office Supplies    443
# San Francisco  Office Supplies    322
# Philadelphia   Office Supplies    312
# Seattle        Office Supplies    249
# Houston        Office Supplies    231
# New York City  Furniture          192
# Chicago        Office Supplies    187
# New York City  Technology         171
# Los Angeles    Furniture          154
# Name: Category, dtype: int64

# %% [markdown]
# office supplies are mojorly odered from NYC

# %%
# city and sub category
df['Sub-Category'].groupby(df['City']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# City           Sub-Category
# New York City  Binders         145
#                Paper           124
# Los Angeles    Paper           118
#                Binders          98
# New York City  Phones           89
# Philadelphia   Binders          87
# New York City  Storage          82
#                Furnishings      78
# Seattle        Binders          75
# Los Angeles    Phones           74
# Name: Sub-Category, dtype: int64

# %% [markdown]
# blinders are ordered from the NYC

# %%
# category and state
df['Category'].groupby(df['State']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# State         Category
# California    Office Supplies    1198
# New York      Office Supplies     684
# Texas         Office Supplies     604
# California    Furniture           444
#               Technology          359
# Pennsylvania  Office Supplies     343
# Washington    Office Supplies     292
# Illinois      Office Supplies     285
# Ohio          Office Supplies     274
# New York      Furniture           236
# Name: Category, dtype: int64

# %% [markdown]
# office supplies are mostly odered from California State

# %%
# state and sub category
df['Sub-Category'].groupby(df['State']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# State       Sub-Category
# California  Paper           289
#             Binders         276
#             Furnishings     191
# New York    Binders         179
# California  Phones          172
#             Art             165
#             Storage         160
# Texas       Binders         153
# New York    Paper           150
# California  Accessories     147
# Name: Sub-Category, dtype: int64

# %% [markdown]
# paper is majorly ordered by california

# %%
# category with numeric variables
sns.pairplot(df,hue='Category')

# %%
# region and category
df['Category'].groupby(df['Region']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Region   Category
# West     Office Supplies    1897
# East     Office Supplies    1712
# Central  Office Supplies    1422
# South    Office Supplies     995
# West     Furniture           707
# East     Furniture           601
# West     Technology          599
# East     Technology          535
# Central  Furniture           481
#          Technology          420
# Name: Category, dtype: int64

# %% [markdown]
# Office supplies are mojorly ordered from west

# %%
# region and sub category
df['Sub-Category'].groupby(df['Region']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Region   Sub-Category
# West     Binders         471
#          Paper           450
# East     Binders         440
#          Paper           378
# Central  Binders         366
#          Paper           321
# West     Furnishings     304
# East     Furnishings     283
# West     Phones          277
# East     Phones          272
# Name: Sub-Category, dtype: int64

# %% [markdown]
# blinders are mostly ordered from west

# %%
# category and sub category
df['Sub-Category'].groupby(df['Category']).value_counts().nlargest(10).sort_values(ascending= False)
# Out:
# Category         Sub-Category
# Office Supplies  Binders         1523
#                  Paper           1370
# Furniture        Furnishings      957
# Technology       Phones           889
# Office Supplies  Storage          846
#                  Art              796
# Technology       Accessories      775
# Furniture        Chairs           617
# Office Supplies  Appliances       466
#                  Labels           364
# Name: Sub-Category, dtype: int64

# %% [markdown]
# mostly blinders are bought in office supplies

# %% [markdown]
# # Correlation between numeric variables

# %%
df_numerical_features.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(df_numerical_features.corr())

# %%
df.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['red','blue'],figsize=(8,5))
plt.ylabel('Profit and sales')
plt.show()

# %%
df.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['blue','red'],figsize=(8,5))
plt.ylabel('Profit and sales')
plt.show()

# %%
df.groupby('Category')[['Profit','Sales']].sum().plot.bar(color=['blue','red'],figsize=(8,5))
plt.ylabel('Profit and sales')
plt.show()

# %%
df.groupby('Sub-Category')[['Sales','Profit']].sum().plot.bar(color=['red','yellow'],figsize=(15,8))
plt.title('Profit& Sales across states')
plt.xlabel('Sub-Category')
plt.ylabel('Profit/loss & Sales')
plt.show()
